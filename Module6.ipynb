# %% [markdown]
# # MODULE 6

# %% [markdown]
# ![Screenshot%202020-07-18%20at%2011.16.15%20AM.png](attachment:Screenshot%202020-07-18%20at%2011.16.15%20AM.png)

# %% [markdown]
# ![Screenshot%202020-07-18%20at%2011.16.29%20AM.png](attachment:Screenshot%202020-07-18%20at%2011.16.29%20AM.png)

# %%
#importing the libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # 6.1

# %% [markdown]
# ![Screenshot%202020-07-17%20at%2010.04.27%20AM.png](attachment:Screenshot%202020-07-17%20at%2010.04.27%20AM.png)

# %%
# Small Cap files
ds1 = pd.read_csv('ASHOKA.csv')
ds2 = pd.read_csv('BOMDYEING.csv')
ds3 = pd.read_csv('CENTURYPLY.csv')
ds4 = pd.read_csv('IDFC.csv')
ds5 = pd.read_csv('LALPATHLAB.csv')
ds6 = pd.read_csv('FORTIS.csv')
ds7 = pd.read_csv('JETAIRWAYS.csv')
ds8 = pd.read_csv('LEMONTREE.csv')
ds9 = pd.read_csv('PVR.csv')
ds10 = pd.read_csv('LEMONTREE.csv')

# %%
# Mid Cap files
dm1 = pd.read_csv('PNB.csv')
dm2 = pd.read_csv('BERGEPAINT.csv')
dm3 = pd.read_csv('CUMMINSIND.csv')
dm4 = pd.read_csv('GODREJIND.csv')
dm5 = pd.read_csv('IDBI.csv')
dm6 = pd.read_csv('IGL.csv')
dm7 = pd.read_csv('MINDTREE.csv')
dm8 = pd.read_csv('MUTHOOTFIN.csv')
dm9 = pd.read_csv('RBLBANK.csv')
dm10 = pd.read_csv('TATAPOWER.csv')

# %%
# Large Cap files
dl1 = pd.read_csv('ASIANPAINT.csv')
dl2 = pd.read_csv('AXISBANK.csv')
dl3 = pd.read_csv('DHFL.csv')
dl4 = pd.read_csv('HDFC.csv')
dl5 = pd.read_csv('RELIANCE.csv')
dl6 = pd.read_csv('HINDUNILVR.csv')
dl7 = pd.read_csv('MARUTI.csv')
dl8 = pd.read_csv('TCS.csv')
dl9 = pd.read_csv('VOLTAS.csv')
dl10 = pd.read_csv('TITAN.csv')

# %%
# new Dataframe to store the closing price of all the imported files
df=pd.DataFrame()

# %%
# Small cap
df['sASHOKA']=ds1['Close Price']
df['sBOMDYEING']=ds2['Close Price']
df['sCENTURYPLY']=ds3['Close Price']
df['sIDFC']=ds4['Close Price']
df['sLALPATHLAB']=ds5['Close Price']
df['sFORTIS']=ds6['Close Price']
df['sJETAIRWAYS']=ds7['Close Price']
df['sLEMONTREE']=ds8['Close Price']
df['sPVR']=ds9['Close Price']
df['sLEMONTREE']=ds10['Close Price']
# Mid Cap
df['mPNB']=dm1['Close Price']
df['mBERGEPAINT']=dm2['Close Price']
df['mCUMMINSIND']=dm3['Close Price']
df['mGODREJIND']=dm4['Close Price']
df['mIDBI']=dm5['Close Price']
df['mIGL']=dm6['Close Price']
df['mMINDTREE']=dm7['Close Price']
df['mMUTHOOTFIN']=dm8['Close Price']
df['mRBLBANK']=dm9['Close Price']
df['mTATAPOWER']=dm10['Close Price']
# Large Cap
df['lASIANPAINT']=dl1['Close Price']
df['lAXISBANK']=dl2['Close Price']
df['lDHFL']=dl3['Close Price']
df['lHDFC']=dl4['Close Price']
df['lRELIANCE']=dl5['Close Price']
df['lHINDUNILVR']=dl6['Close Price']
df['lMARUTI']=dl7['Close Price']
df['lTCS']=dl8['Close Price']
df['lVOLTAS']=dl9['Close Price']
df['lTITAN']=dl10['Close Price']

# %%
df.head()
# Out:
#    sASHOKA  sBOMDYEING  sCENTURYPLY  sIDFC  sLALPATHLAB  sFORTIS  sJETAIRWAYS  \
# 0   216.05       82.20       266.65  63.70       900.60   205.25       527.50
# 1   214.90       83.40       266.10  64.25       910.95   207.90       534.15
# 2   217.00       82.25       264.85  63.35       911.70   205.90       528.90
# 3   209.65       78.95       260.35  61.50       909.75   196.85       522.70
# 4   206.25       77.15       254.05  61.15       910.25   203.55       520.40
#
#    sLEMONTREE     sPVR    mPNB  ...  lASIANPAINT  lAXISBANK   lDHFL    lHDFC  \
# 0       71.65  1524.95  166.80  ...      1148.05      500.1   431.4  1559.50
# 1       66.85  1539.00  174.15  ...      1142.85      501.5  1009.9   205.00
# 2       66.95  1530.30  165.05  ...      1154.95      502.8  1055.2  1566.55
# 3       66.40  1515.05  158.50  ...      1151.35      492.0  1070.0  1552.50
# 4       67.70  1513.55  155.20  ...      1123.15      501.7  1050.0   207.00
#
# ...

# %% [markdown]
# # 6.2

# %% [markdown]
# ![Screenshot%202020-07-17%20at%2010.04.38%20AM.png](attachment:Screenshot%202020-07-17%20at%2010.04.38%20AM.png)

# %%
# new DataFrame
dpc=pd.DataFrame()
# daily percentage change of all the stocks
dpc=df.pct_change().fillna(0)

# %%
dpc.head()
# Out:
#     sASHOKA  sBOMDYEING  sCENTURYPLY     sIDFC  sLALPATHLAB   sFORTIS  \
# 0  0.000000    0.000000     0.000000  0.000000     0.000000  0.000000
# 1 -0.005323    0.014599    -0.002063  0.008634     0.011492  0.012911
# 2  0.009772   -0.013789    -0.004697 -0.014008     0.000823 -0.009620
# 3 -0.033871   -0.040122    -0.016991 -0.029203    -0.002139 -0.043953
# 4 -0.016218   -0.022799    -0.024198 -0.005691     0.000550  0.034036
#
#    sJETAIRWAYS  sLEMONTREE      sPVR      mPNB  ...  lASIANPAINT  lAXISBANK  \
# 0     0.000000    0.000000  0.000000  0.000000  ...     0.000000   0.000000
# 1     0.012607   -0.066992  0.009213  0.044065  ...    -0.004529   0.002799
# 2    -0.009829    0.001496 -0.005653 -0.052254  ...     0.010588   0.002592
# 3    -0.011722   -0.008215 -0.009965 -0.039685  ...    -0.003117  -0.021480
# 4    -0.004400    0.019578 -0.000990 -0.020820  ...    -0.024493   0.019715
#
#       lDHFL     lHDFC  lRELIANCE  lHINDUNILVR   lMARUTI      lTCS   lVOLTAS  \
# ...

# %%
# creating new dataframe 
value=pd.DataFrame()
value['mean']=dpc.mean()
value['std']=dpc.std()

# %%
value.head()
# Out:
#                  mean       std
# sASHOKA     -0.000826  0.027876
# sBOMDYEING   0.001297  0.037939
# sCENTURYPLY -0.000722  0.023616
# sIDFC       -0.000794  0.022277
# sLALPATHLAB  0.000309  0.016640

# %%
# Annual mean return
value['Return']=value['mean']*252

# %%
# Annual volatility
value['Volatility']=value['std']*((252)**0.5)

# %%
value.head()
# Out:
#                  mean       std    Return  Volatility
# sASHOKA     -0.000826  0.027876 -0.208086    0.442525
# sBOMDYEING   0.001297  0.037939  0.326958    0.602258
# sCENTURYPLY -0.000722  0.023616 -0.181969    0.374888
# sIDFC       -0.000794  0.022277 -0.200083    0.353631
# sLALPATHLAB  0.000309  0.016640  0.077963    0.264150

# %% [markdown]
# # 6.3

# %% [markdown]
# ![Screenshot%202020-07-17%20at%2010.35.35%20AM.png](attachment:Screenshot%202020-07-17%20at%2010.35.35%20AM.png)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering

# %%
value.drop(['mean','std'],axis=1,inplace=True)

# %%
value
# Out:
#                  Return  Volatility
# sASHOKA       -0.208086    0.442525
# sBOMDYEING     0.326958    0.602258
# sCENTURYPLY   -0.181969    0.374888
# sIDFC         -0.200083    0.353631
# sLALPATHLAB    0.077963    0.264150
# sFORTIS       -0.137019    0.421056
# sJETAIRWAYS   -0.480045    0.624221
# sLEMONTREE     0.030927    0.289258
# sPVR           0.108310    0.309876
# mPNB          -0.238955    0.544837
# mBERGEPAINT    0.108714    0.267396
# mCUMMINSIND   -0.177269    0.296244
# mGODREJIND    -0.090067    0.266380
# mIDBI         -0.295409    0.453328
# mIGL          -0.131495    0.650467
# mMINDTREE      0.391775    0.341140
# mMUTHOOTFIN  104.385879   18.283002
# mRBLBANK       0.113267    0.258470
# mTATAPOWER    -0.090766    0.307984
# lASIANPAINT    0.101044    0.209194
# lAXISBANK      0.234770    0.277614
# lDHFL         27.795208    8.416019
# lHDFC        454.136327   43.096124
# lRELIANCE      0.094928    0.438645
# lHINDUNILVR    0.294373    0.193775
# ...

# %%
# Dropping the outliers 
value.drop(value.loc[value['Return']>1].index, inplace=True)

# %%
# transforming our dataset into array
X = StandardScaler().fit_transform(value)

# %%
#for each value of k, we initialise k_means and use inertia to identify the sum of squared distances of values to the nearest cluster centre
sum_of_squared_distances = []
num = range(1,15)
for i in num:
    k_means = KMeans(n_clusters=i)
    model = k_means.fit(X)
    sum_of_squared_distances.append(k_means.inertia_)

# %%
# Elbow curve plot
plt.figure(figsize=(10,5))
plt.plot(K, sum_of_squared_distances,'r*-')
plt.xlabel('num')
plt.ylabel('Sum of Squared Distances')
plt.title('Elbow method for optimal no. of clusters',fontsize=15)
plt.show()

# %% [markdown]
# ##### We can see the elbow point at 8, i.e. we can have 8 optimal clusters for our model

# %% [markdown]
# # 6.4

# %% [markdown]
# ![Screenshot%202020-07-17%20at%2012.04.03%20PM.png](attachment:Screenshot%202020-07-17%20at%2012.04.03%20PM.png)

# %%
# Values plotted
plt.figure(figsize=(10,5))
plt.scatter(X[:,0],X[:,1])
plt.title('Position of Datavalues',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Position of Datavalues')

# %%
# optimisation gives clusters value to be 2 
kmeans = KMeans(n_clusters=8)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# centres of the cluster formed
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 0.49847209, -0.83136903],
#        [-0.89824411,  1.86146489],
#        [-0.98452373,  0.35636828],
#        [ 1.86253934, -0.25422326],
#        [ 1.39283441,  1.89823434],
#        [ 0.32222499,  0.56159535],
#        [-0.603652  , -0.59253181],
#        [-2.21702104,  2.07353608]])

# %%
# predicting which values belong to which cluster
value['Pred']=kmeans.labels_
value
# Out:
#                Return  Volatility  Pred
# sASHOKA     -0.208086    0.442525     2
# sBOMDYEING   0.326958    0.602258     4
# sCENTURYPLY -0.181969    0.374888     2
# sIDFC       -0.200083    0.353631     2
# sLALPATHLAB  0.077963    0.264150     0
# sFORTIS     -0.137019    0.421056     2
# sJETAIRWAYS -0.480045    0.624221     7
# sLEMONTREE   0.030927    0.289258     0
# sPVR         0.108310    0.309876     0
# mPNB        -0.238955    0.544837     1
# mBERGEPAINT  0.108714    0.267396     0
# mCUMMINSIND -0.177269    0.296244     6
# mGODREJIND  -0.090067    0.266380     6
# mIDBI       -0.295409    0.453328     2
# mIGL        -0.131495    0.650467     1
# mMINDTREE    0.391775    0.341140     3
# mRBLBANK     0.113267    0.258470     0
# mTATAPOWER  -0.090766    0.307984     6
# lASIANPAINT  0.101044    0.209194     0
# lAXISBANK    0.234770    0.277614     0
# lRELIANCE    0.094928    0.438645     5
# lHINDUNILVR  0.294373    0.193775     0
# ...

# %%
fig, ax = plt.subplots(figsize=(12,6))
# scatter plot to show clusters
ax.scatter(X[:,0],X[:,1], c=value['Pred'], cmap='nipy_spectral')
# produce a legend with the unique colors from the scatter
ax.legend(*scatter.legend_elements(), loc="lower left", title="Clusters")
plt.title('Datavalues belonging to Clusters',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Datavalues belonging to Clusters')

# %%
fig, ax = plt.subplots(figsize=(12,6))
# scatter plot to show clusters centre
ax.scatter(X[:,0],X[:,1], c=value['Pred'], cmap='nipy_spectral')
# produce a legend with the unique colors from the scatter
ax.legend(*scatter.legend_elements(), loc="lower left", title="Clusters")
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1],marker=(5,1,0),color='k',s=200)
plt.title('Position of Centres for different clusters',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Position of Centres for different clusters')

# %% [markdown]
# # Thank You!
